# %%
import pathlib

# %%
templates_path=pathlib.Path("/content/drive/MyDrive/templates")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
templates_path.mkdir(parents=True, exist_ok=True)

# %%
index_html=templates_path/'index.html'

# %%
index_html.write_text("""<!DOCTYPE html>
<html lang='en'>
  <head>
    <title>Flight Fare Price Prediction</title>
    <link rel="stylesheet" type="text/css" href="{{ url_for('static', filename='style.css') }}">
  </head>
  <body>
  <div class='container'>
    <h2>Get an Estimated Fare for Your Flight</h2>
    <p>Enter your flight details to get an estimated ticket price based on airline, route, class, and other travel information. This prediction is powered by a machine learning model trained on real-world flight data.</p>
    <form method='POST'>
      <label for='airline'>Select Airline:</label>
      <select id='airline' name='airline' required>
        <option value=''>--select--</option>
        <option value='Vistara'>Vistara</option>
        <option value='Air_India'>Air India</option>
        <option value='Indigo'>Indigo</option>
        <option value='GO_FIRST'>Go First</option>
        <option value='AirAsia'>Air Asia</option>
        <option value='SpiceJet'>SpiceJet</option>
      </select><br><br>
      <label for='source_city'>Flying From:</label>
      <select id='source_city' name='source_city' required>
        <option value=''>--select--</option>
        <option value='Delhi'>Delhi</option>
        <option value='Bangalore'>Bangalore</option>
        <option value='Chennai'>Chennai</option>
        <option value='Hyderabad'>Hyderabad</option>
        <option value='Kolkata'>Kolkata</option>
        <option value='Mumbai'>Mumbai</option>
      </select><br><br>
      <label for='destination_city'>Flying to:</label>
      <select id='destination_city' name='destination_city' required>
        <option value=''>--select--</option>
        <option value='Delhi'>Delhi</option>
        <option value='Bangalore'>Bangalore</option>
        <option value='Chennai'>Chennai</option>
        <option value='Hyderabad'>Hyderabad</option>
        <option value='Kolkata'>Kolkata</option>
        <option value='Mumbai'>Mumbai</option>
      </select><br><br>
      <label for='departure_time'>Flight Departure Time:</label>
      <select id='departure_time' name='departure_time' required>
        <option value=''>--select--</option>
        <option value='Early_Morning'>Early Morning</option>
        <option value='Morning'>Morning</option>
        <option value='Afternoon'>Afternoon</option>
        <option value='Evening'>Evening</option>
        <option value='Night'>Night</option>
        <option value='Late_Night'>Late Night</option>
      </select><br><br>
      <label for='arrival_time'>Flight Arrival Time:</label>
      <select id='arrival_time' name='arrival_time' required>
        <option value=''>--select--</option>
        <option value='Early_Morning'>Early Morning</option>
        <option value='Morning'>Morning</option>
        <option value='Afternoon'>Afternoon</option>
        <option value='Evening'>Evening</option>
        <option value='Night'>Night</option>
        <option value='Late_Night'>Late Night</option>
      </select><br><br>
      <label for='stops'>Number of Stops:</label>
      <select id='stops' name='stops' required>
        <option value=''>--select--</option>
        <option value='zero'>Zero</option>
        <option value='one'>One</option>
        <option value='two_or_more'>Two or More</option>
      </select><br><br>
      <label for='class'>Class:</label>
      <select id='class' name='class' required>
        <option value=''>--select--</option>
        <option value='Economy'>Economy</option>
        <option value='Business'>Business</option>
      </select><br><br>
      <label for='duration'>Expected Duration(in hours):</label>
      <input type='number' step='0.01' id='duration' name='duration' placeholder='e.g. 3.44' required><br><br>
      <label for='days_left'>Days Left to Travel:</label>
      <input type='number' id='days_left' name='days_left' placeholder='e.g. 7' required><br><br>
      <input type='submit' name='SUBMIT'>
     </form>
    </div>
    </body>
</html>""")
# Out:
# 3968

# %%
result_html=templates_path/'result.html'

# %%
result_html
# Out:
# PosixPath('/content/drive/MyDrive/templates/result.html')

# %%
result_html.write_text("""<!DOCTYPE html>
<html lang='en'>
<head>
<div class='container'>
  <title>Estimated Flight Fare</title>
  <link rel="stylesheet" type="text/css" href="{{ url_for('static', filename='style.css') }}">
</head>
<body>
  <h2>Your Estimated Flight Fare</h2>
  <p>Based on the travel details you provided, here's the estimated fare price:</p>
  <h3 style='color: green;'>₹ {{ prediction }} </h3>
  <br>
  <a href='/'>Try Another Prediction</a>
</div>
</body>
</html>""")
# Out:
# 458

# %%
static_path=pathlib.Path('/content/drive/MyDrive/static')

# %%
static_path.mkdir(parents=True, exist_ok=True)

# %%
style_path=static_path/'style.css'

# %%
style_path.write_text("""
html, body {
  height: 100%;
  margin: 0;
  padding: 0;
}

body {
  font-family: Arial, sans-serif;
  background-image: url('/static/background.jpg');
  background-size: cover;
  background-repeat: no-repeat;
  background-position: center;
  background-color: #f4f4f9; /* Fallback */
  color: #333;
  padding: 20px;
  min-height: 100vh;
  box-sizing: border-box;
  display: flex;
  flex-direction: column;
  justify-content: center;
  align-items: center;
  text-align: center;
}

/* Responsive background handling for smaller screens */
@media (max-width: 768px) {
  body {
    background-size: cover;
    background-position: center top;
    background-attachment: scroll;
  }

  form {
    width: 90%;
  }

  h2 {
    font-size: 36px;  /* Adjusted for mobile */
  }

  p {
    font-size: 22px;  /* Adjusted for mobile */
  }

  .result {
    font-size: 32px;  /* Adjusted for mobile */
  }
}

form {
  background-color: white;
  padding: 25px 30px;
  max-width: 500px;
  width: 100%;
  margin: auto;
  border-radius: 12px;
  box-shadow: 0 0 12px rgba(0,0,0,0.15);
}

label {
  display: block;
  margin-top: 12px;
  font-weight: bold;
  text-align: left;
}

input, select {
  width: 100%;
  padding: 10px;
  margin-top: 5px;
  border-radius: 6px;
  border: 1px solid #ccc;
  box-sizing: border-box;
}

input[type="submit"] {
  background-color: #28a745;
  color: white;
  border: none;
  cursor: pointer;
  margin-top: 20px;
  font-weight: bold;
  padding: 10px 0;
}

input[type="submit"]:hover {
  background-color: #218838;
}

h2 {
  color: #2c3e50;
  margin-bottom: 28px;
  font-size: 32px;  /* Increased for better visibility */
}

p {
  font-size: 20px;   /* Increased for readability */
  margin-bottom: 20px;
  line-height: 1.6;
}

.result {
  color: #007bff;
  font-size: 28px;   /* More prominent prediction */
  font-weight: bold;
}

/* Optional: Container styling for result.html */
.container {
  background-color: rgba(255, 255, 255, 0.95);
  padding: 30px;
  border-radius: 12px;
  max-width: 500px;
  width: 90%;
  box-shadow: 0 0 15px rgba(0,0,0,0.15);
}
""")
# Out:
# 2074

# %%
background_path=static_path/'background.jpg'

# %%
background_path
# Out:
# PosixPath('/content/drive/MyDrive/static/background.jpg')

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-c3871c0c-7bac-4f54-b131-b0ea7bdf9427" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c3871c0c-7bac-4f54-b131-b0ea7bdf9427">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import shutil

# %%
uploaded_filename=list(uploaded.keys())[0]

# %%
uploaded_filename
# Out:
# 'upscalemedia-transformed.jpg'

# %%
destination_path=static_path/'background.jpg'

# %%
shutil.move(uploaded_filename, destination_path)
# Out:
# PosixPath('/content/drive/MyDrive/static/background.jpg')
